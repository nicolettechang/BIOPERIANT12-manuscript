# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mean-biomes-from-Fay-&amp;-McKinley-2014,-below-30S" data-toc-modified-id="Mean-biomes-from-Fay-&amp;-McKinley-2014,-below-30S-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Mean biomes from Fay &amp; McKinley 2014, below 30S</a></span><ul class="toc-item"><li><span><a href="#Model-mean-biome" data-toc-modified-id="Model-mean-biome-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Model mean biome</a></span></li><li><span><a href="#Model-undefined-regions-from-overlap" data-toc-modified-id="Model-undefined-regions-from-overlap-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Model undefined regions from overlap</a></span></li><li><span><a href="#Obs-biome" data-toc-modified-id="Obs-biome-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Obs biome</a></span></li></ul></li><li><span><a href="#Find-regions-where-biomes-overlap/differ" data-toc-modified-id="Find-regions-where-biomes-overlap/differ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Find regions where biomes overlap/differ</a></span><ul class="toc-item"><li><span><a href="#where-the-failure-is-due-to-poor-model-definition" data-toc-modified-id="where-the-failure-is-due-to-poor-model-definition-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>where the failure is due to poor model definition</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Plot</a></span></li></ul></li><li><span><a href="#Plot-variables-at-mismatch" data-toc-modified-id="Plot-variables-at-mismatch-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Plot variables at mismatch</a></span><ul class="toc-item"><li><span><a href="#Get-clim" data-toc-modified-id="Get-clim-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Get clim</a></span></li><li><span><a href="#Plot-info" data-toc-modified-id="Plot-info-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Plot info</a></span></li><li><span><a href="#[-Plot-fxn-]" data-toc-modified-id="[-Plot-fxn-]-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>[ Plot fxn ]</a></span></li><li><span><a href="#SP-STPS-+-SA-STPS-(Pacific,-Atlantic):-SST-≥-8°C,-Summer-Chl-a-<-0.25-g-m-3,-max-MLD-≤-150m" data-toc-modified-id="SP-STPS-+-SA-STPS-(Pacific,-Atlantic):-SST-≥-8°C,-Summer-Chl-a-<-0.25-g-m-3,-max-MLD-≤-150m-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>SP-STPS + SA-STPS (Pacific, Atlantic): SST ≥ 8°C, Summer Chl-a &lt; 0.25 g m-3, max MLD ≤ 150m</a></span></li><li><span><a href="#IND-STPS-(Indian):-SST-≥-11°C,-Summer-Chl-a-<-0.25-g-m-3.-Biome-14" data-toc-modified-id="IND-STPS-(Indian):-SST-≥-11°C,-Summer-Chl-a-<-0.25-g-m-3.-Biome-14-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>IND-STPS (Indian): SST ≥ 11°C, Summer Chl-a &lt; 0.25 g m-3. Biome 14</a></span></li><li><span><a href="#SO-STSS-Criteria:" data-toc-modified-id="SO-STSS-Criteria:-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>SO-STSS Criteria:</a></span></li><li><span><a href="#SH_SPSS-Criteria:-SST-<-8-degree-C-Referred-as-biome-16." data-toc-modified-id="SH_SPSS-Criteria:-SST-<-8-degree-C-Referred-as-biome-16.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>SH_SPSS Criteria: SST &lt; 8 degree C Referred as biome 16.</a></span></li></ul></li><li><span><a href="#Put-images-together" data-toc-modified-id="Put-images-together-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Put images together</a></span><ul class="toc-item"><li><span><a href="#Only-subtropical-zones" data-toc-modified-id="Only-subtropical-zones-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Only subtropical zones</a></span></li><li><span><a href="#Include-SPSS" data-toc-modified-id="Include-SPSS-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Include SPSS</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Model vs obs biome definition

# %%
import sys
import os
src_path = os.path.abspath(os.path.join(os.getcwd(), '../src'))
sys.path.append(src_path)
import bp12_tools as bp12
import bp12_tools.plot_utils as pu

import pandas as pd
import numpy as np
import xarray as xr
import xesmf as xe

import matplotlib.pyplot as plt
import matplotlib as mpl
from cartopy import crs as ccrs, feature as cfeature
from cmcrameri import cm
import cmocean as cmo

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Biomes 7, 13, 14, 15, 16 and 17 exist in Fay & McKinley 2014 in the Southern Ocean. So I need to define them in BIOPERIANT12.
#
# Biome 7 = South Pacific Subtropical Permanently Stratified = SP-STPS
# Biome 13 = South Atlantic Subtropical Permanently Stratified = SA-STPS
# Biome 14 = Indian Ocean Subtropical Permanently Stratified = IND STPS
# Biome 15 = Southern Ocean Subtropical Seasonally Stratified = SO-STSS
# Biome 16 =Southern Ocean Subpolar Seasonally Stratified = SO-SPSS
# Biome 17 =Southern Ocean Ice = SO-ICE

# %% [markdown]
# ---

# %% [markdown]
# ## Mean biomes from Fay & McKinley 2014, below 30S

# %% [markdown]
# ### Model mean biome

# %%
Model_product = xr.open_dataset(f"../data/BIOMES/BIOPERIANT12onFK2014_biomes_clim_monthly.nc")
meanbiomerg_mdl  = Model_product.biomes

# %% [markdown]
# ### Model undefined regions from overlap

# %%
bundef_mdl = xr.open_dataset("../data/BIOMES/BIOPERIANT12onFK14_meanbiome_undef.nc").biomes

# %% [markdown]
# ### Obs biome

# %%
Fay_product = xr.open_dataset("../data/BIOMES/FayMcKinley2014_Biomes.nc")
ds_meanbiomes_obs = Fay_product.MeanBiomes
meanbiomes_obs = ds_meanbiomes_obs.where(ds_meanbiomes_obs.lat<-30, np.nan)
meanbiomes_obs = meanbiomes_obs.transpose()

# %% [markdown]
# ## Find regions where biomes overlap/differ

# %%
meanbiome_o = meanbiomes_obs.copy()
b17 = meanbiome_o.where((meanbiomerg_mdl==17) & (meanbiomes_obs==17),0)
b16 = meanbiome_o.where((meanbiomerg_mdl==16) & (meanbiomes_obs==16),0)
b15 = meanbiome_o.where((meanbiomerg_mdl==15) & (meanbiomes_obs==15),0)
b14 = meanbiome_o.where((meanbiomerg_mdl==14) & (meanbiomes_obs==14),0)
b13 = meanbiome_o.where((meanbiomerg_mdl==13) & (meanbiomes_obs==13),0)
b7  = meanbiome_o.where((meanbiomerg_mdl== 7) & (meanbiomes_obs== 7),0)
btot_mean = b17+ b16 +b15 +b14 +b13+ b7
btot_mean = btot_mean.where(btot_mean > 6, np.nan)

# %%
b17 = meanbiome_o.where((meanbiomerg_mdl!=17) & (meanbiomes_obs==17),0)
b16 = meanbiome_o.where((meanbiomerg_mdl!=16) & (meanbiomes_obs==16),0)
b15 = meanbiome_o.where((meanbiomerg_mdl!=15) & (meanbiomes_obs==15),0)
b14 = meanbiome_o.where((meanbiomerg_mdl!=14) & (meanbiomes_obs==14),0)
b13 = meanbiome_o.where((meanbiomerg_mdl!=13) & (meanbiomes_obs==13),0)
b7  = meanbiome_o.where((meanbiomerg_mdl!= 7) & (meanbiomes_obs== 7),0)
bdiff_mean = b17+ b16 +b15 +b14 +b13+ b7
bdiff_mean = bdiff_mean.where(bdiff_mean > 6, np.nan)

# %% [markdown]
# ### where the failure is due to poor model definition

# %%
b14a = bdiff_mean.where((bdiff_mean==14) & (bundef_mdl==14),0)
b13a = bdiff_mean.where((bdiff_mean==13) & (bundef_mdl==13),0)
b7a  = bdiff_mean.where((bdiff_mean== 7) & (bundef_mdl== 7),0)
b_overlap = b14a + b13a + b7a
b_overlap = b_overlap.where(b_overlap > 6, np.nan)

# %%
plt.pcolor(b_overlap.lon, b_overlap.lat, b_overlap, hatch='.', alpha=0.)
plt.colorbar()

# %% [markdown]
# ### Plot

# %%
bounds = np.array([7, 13, 14, 15, 16, 17, 18])
colors_fk = [pu.formatting_plots.get_biome_colors(biomenum) for biomenum in bounds]
cmap_biome = (mpl.colors.ListedColormap(colors_fk))
norm_biome = mpl.colors.BoundaryNorm(bounds, cmap_biome.N)

# %%
cbar_ticks = [9.5,13.5,14.5,15.5,16.5,17.5]
cbar_ticklbls = ['SP-STPS', 'SA-STPS', 'IND-STPS', 'SO-STSS', 'SO-SPSS', 'SO-ICE']

fig = plt.figure(figsize=(16,9))

######### --- MODEL-BASED MEAN BIOMES (1998-2006) --- ########### 
ax1 = fig.add_subplot(1,3,1, projection = ccrs.Stereographic(central_latitude=-90))
mesh = ax1.pcolormesh(meanbiomerg_mdl.lon, meanbiomerg_mdl.lat, meanbiomerg_mdl, 
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=0)
cb = plt.colorbar(mesh, ticks=cbar_ticks, orientation='vertical', shrink=0.4, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
plt.title(f'(a) BIOPERIANT12', loc='left', fontsize=12)
pu.map_plots.map_decorator(ax1)
pu.map_plots.add_fronts(ax1, -1, dataset="mdl")

######### --- OBSERVATION-BASED CORE BIOMES-- ###########
ax2 = fig.add_subplot(1,3,2, projection = ccrs.Stereographic(central_latitude=-90))
plt.title('(b) OBS', loc='left', fontsize=12)
mesh2 = ax2.pcolormesh(meanbiomes_obs.lon, meanbiomes_obs.lat, meanbiomes_obs, 
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=0)
cb = plt.colorbar(mesh2, ticks=cbar_ticks, orientation='vertical', shrink=0.4, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
pu.map_plots.map_decorator(ax2)
pu.map_plots.add_fronts(ax2, -1, dataset="obs")

plt.tight_layout()

# %%
fig = plt.figure(figsize=(12,6))
ax3 = fig.add_subplot(2,3,3, projection = ccrs.Stereographic(central_latitude=-90))
plt.title('(c) OBS-MODEL (mismatch)', loc='left', fontsize=12)
mesh2 = ax3.contour(b_overlap.lon, b_overlap.lat, b_overlap,
                     transform=ccrs.PlateCarree(),zorder=0)
#cb = plt.colorbar(mesh2, ticks=cbar_ticks, orientation='vertical', shrink=0.8, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
pu.map_plots.map_decorator(ax3)

# %%
cbar_ticks = [9.5,13.5,14.5,15.5,16.5,17.5]
cbar_ticklbls = ['SP-STPS', 'SA-STPS', 'IND-STPS', 'SO-STSS', 'SO-SPSS', 'SO-ICE']

fig = plt.figure(figsize=(12,6))

######### ----- ########### 
ax1 = fig.add_subplot(2,3,1, projection = ccrs.Stereographic(central_latitude=-90))
mesh = ax1.pcolormesh(btot_mean.lon, btot_mean.lat, btot_mean, 
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=0)
cb = plt.colorbar(mesh, ticks=cbar_ticks, orientation='vertical', shrink=0.8, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  

plt.title(f'(a) MODEL=OBS (match)', loc='left', fontsize=12)
pu.map_plots.map_decorator(ax1)
#pu.map_plots.add_fronts(ax1, -1, dataset="mdl")

######### ---- ###########
ax2 = fig.add_subplot(2,3,2, projection = ccrs.Stereographic(central_latitude=-90))
plt.title('(b) OBS-MODEL (mismatch)', loc='left', fontsize=12)
mesh2 = ax2.pcolormesh(bdiff_mean.lon, bdiff_mean.lat, bdiff_mean, 
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=0)
cb = plt.colorbar(mesh2, ticks=cbar_ticks, orientation='vertical', shrink=0.8, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
pu.map_plots.map_decorator(ax2)
#pu.map_plots.add_fronts(ax2, -1, dataset="mdl")


######### --- OBSERVATION-BASED CORE BIOMES-- ###########
ax3 = fig.add_subplot(2,3,3, projection = ccrs.Stereographic(central_latitude=-90))
plt.title('(c) OBS-MODEL (mismatch)', loc='left', fontsize=12)
bdiff_mean_ST = bdiff_mean.where(bdiff_mean<15.1, np.nan)
ax3.pcolormesh(bdiff_mean.lon, bdiff_mean.lat, bdiff_mean_ST, alpha=0.3,
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=0)
mesh3 = ax3.pcolormesh(b_overlap.lon, b_overlap.lat, b_overlap,
                     norm=norm_biome, cmap=cmap_biome, 
                     transform=ccrs.PlateCarree(),zorder=6)
cb = plt.colorbar(mesh3, ticks=cbar_ticks, orientation='vertical', shrink=0.8, aspect = 25, pad = 0.08)


cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
pu.map_plots.map_decorator(ax3)
#pu.map_plots.add_fronts(ax2, -1, dataset="mdl")

# %%
#ax3.pcolor(b_overlap.lon, b_overlap.lat, b_overlap, hatch='//', alpha=0., zorder=5)

# %%
fig = plt.figure(figsize=(12,9))
bdiff_mean_ST = bdiff_mean.where(bdiff_mean<15.1, np.nan)

ax1 = fig.add_subplot(3,1,1)
ax1.pcolormesh(bdiff_mean.lon, bdiff_mean.lat, bdiff_mean_ST, alpha=0.3,
                     norm=norm_biome, cmap=cmap_biome,zorder=0)
mesh3 = ax1.pcolormesh(b_overlap.lon, b_overlap.lat, b_overlap,norm=norm_biome, cmap=cmap_biome,zorder=6)
cb = plt.colorbar(mesh3, ticks=cbar_ticks, orientation='vertical', shrink=0.8, aspect = 25, pad = 0.08)
cb.ax.set_title('biomes', fontsize=10, fontweight = 'normal', loc='left')
cb.ax.set_yticklabels(cbar_ticklbls)  
plt.ylim([-55,-30])
plt.grid()

# %% [markdown]
# ## Plot variables at mismatch

# %% [markdown]
# ### Get clim

# %%
ds = xr.open_dataset("../data/BIOMES/BIOPERIANT12onFK2014_biomeinputs_clim_monthly.nc")
sst_rgmdl = ds.sst
mld_rgmdl = ds.mld
chl_rgmdl = ds.chl

# %% [markdown]
# ### Plot info

# %%
varunit = pu.formatting_plots.get_unit_mplstr(bp12.model_utils.get_varinfo('votemper','unit'))
t_label = f" SST {varunit}"
mld_label = f"MLD max [m]"
varunit = pu.formatting_plots.get_unit_mplstr(bp12.model_utils.get_varinfo('chl','unit'))
chl_label = f"Chl-a summer {varunit}"

# %% [markdown]
# ### [ Plot fxn ]

# %%
def get_mismatch(biomenum_in):
    if len(biomenum_in) == 1: 
        sstb = sst_rgmdl.where(bdiff_mean==biomenum_in[0])
        mldb = mld_rgmdl.where(bdiff_mean==biomenum_in[0])
        chlb = chl_rgmdl.where(bdiff_mean==biomenum_in[0]) 
    if len(biomenum_in) == 2: 
        sstb = sst_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1]))
        mldb = mld_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1]))
        chlb = chl_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1]))
    if len(biomenum_in) == 3: 
        sstb = sst_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1])|(bdiff_mean==biomenum_in[2]))
        mldb = mld_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1])|(bdiff_mean==biomenum_in[2]))
        chlb = chl_rgmdl.where((bdiff_mean==biomenum_in[0])|(bdiff_mean==biomenum_in[1])|(bdiff_mean==biomenum_in[2]))
    return sstb, mldb, chlb
            
def plot_vars(biomenum, biomestr, fignums):
    
    sst_mismatch, mld_mismatch, chl_mismatch = get_mismatch(biomenum)
    
    ax1 = fig.add_subplot(2, 3, 1, projection = ccrs.Stereographic(central_latitude=-90))
    plt.title(f'({fignums[0]}) SST {biomestr} mismatch',loc='left',fontsize=12)
    mesh = ax1.pcolormesh(sst_mismatch.lon, sst_mismatch.lat, sst_mismatch,
                         cmap=cm.roma_r, vmin=0, vmax=16,
                         transform=ccrs.PlateCarree(), zorder=0)
    cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='both')
    cb.set_label(t_label, rotation=-90, labelpad=13)
    pu.map_plots.map_decorator(ax1)
    pu.map_plots.add_biomes(ax1, "mdl", 0.4)

    ax2 = fig.add_subplot(2, 3, 2, projection = ccrs.Stereographic(central_latitude=-90))
    plt.title(f'({fignums[1]}) Chl-a {biomestr} mismatch',loc='left',fontsize=12)
    mesh = ax2.pcolormesh(chl_mismatch.lon, chl_mismatch.lat, chl_mismatch,
                         cmap=cm.roma_r, vmin=0, vmax =0.5,
                         transform=ccrs.PlateCarree(), zorder=0)
    cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
    cb.set_label(chl_label, rotation=-90, labelpad=13)
    pu.map_plots.map_decorator(ax2)
    pu.map_plots.add_biomes(ax2, "mdl", 0.4)
    
    ax3 = fig.add_subplot(2, 3, 3, projection = ccrs.Stereographic(central_latitude=-90))
    plt.title(f'({fignums[2]}) MLD {biomestr} mismatch',loc='left',fontsize=12)
    mesh = ax3.pcolormesh(mld_mismatch.lon, mld_mismatch.lat, mld_mismatch,
                         cmap=cm.roma_r, vmin=0, vmax=300,
                         transform=ccrs.PlateCarree(), zorder=0)
    cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
    cb.set_label(mld_label, rotation=-90, labelpad=13)
    pu.map_plots.map_decorator(ax3)
    pu.map_plots.add_biomes(ax3, "mdl", 0.4)
    
    return

# %% [markdown]
# ### SP-STPS + SA-STPS (Pacific, Atlantic): SST ≥ 8°C, Summer Chl-a < 0.25 g m-3, max MLD ≤ 150m

# %%
str01 = f"Subtropical Permanently Stratified STPS (South Pacific, South Atlantic): SST ≥ 8 \u00b0C, Summer Chl-a < 0.25 mg m\u207B\u00B3, max MLD ≤ 150 m"

# %%
biome, biomestr = [7,13], "STPS"
fignums = ("a", "b", "c")
fig = plt.figure(figsize=(12, 6))
#plot_vars(biome, biomestr, fignums)

sst_mismatch, mld_mismatch, chl_mismatch = get_mismatch(biome)

ax1 = fig.add_subplot(2, 3, 1, projection = ccrs.Stereographic(central_latitude=-90))
plt.title(f'({fignums[0]}) SST {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax1.pcolormesh(sst_mismatch.lon, sst_mismatch.lat, sst_mismatch,
                     cmap=cm.roma_r, vmin=8, vmax=16,
                     transform=ccrs.PlateCarree(), zorder=0)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='both')
cb.set_label(t_label, rotation=-90, labelpad=13)
pu.map_plots.map_decorator(ax1)
pu.map_plots.add_biomes(ax1, "mdl", 0.4)

ax2 = fig.add_subplot(2, 3, 2, projection = ccrs.Stereographic(central_latitude=-90))
plt.title(f'({fignums[1]}) Chl-a {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax2.pcolormesh(chl_mismatch.lon, chl_mismatch.lat, chl_mismatch,
                     cmap=cm.roma_r, vmin=0., vmax =0.25,
                     transform=ccrs.PlateCarree(), zorder=0)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(chl_label, rotation=-90, labelpad=13)
pu.map_plots.map_decorator(ax2)
pu.map_plots.add_biomes(ax2, "mdl", 0.4)

ax3 = fig.add_subplot(2, 3, 3, projection = ccrs.Stereographic(central_latitude=-90))
plt.title(f'({fignums[2]}) MLD {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax3.pcolormesh(mld_mismatch.lon, mld_mismatch.lat, mld_mismatch,
                     cmap=cm.roma_r, vmin=0, vmax=150,
                     transform=ccrs.PlateCarree(), zorder=0)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(mld_label, rotation=-90, labelpad=13)
pu.map_plots.map_decorator(ax3)
pu.map_plots.add_biomes(ax3, "mdl", 0.4)

# %%
def basin_bdy():
    plt.plot([20,20],[-55,-30],'grey')
    plt.plot([145,145],[-55,-30],'grey')
    plt.plot([-70,-70],[-55,-30],'grey')
    

biome, biomestr = [7,13,14], "STPS"
fignums = ("a", "b", "c")
plt.rcParams['hatch.linewidth'] = 0.5
plt.rcParams.update({'hatch.color': 'grey'})


fig = plt.figure(figsize=(12, 9))

sst_mismatch, mld_mismatch, chl_mismatch = get_mismatch(biome)

ax1 = fig.add_subplot(3,1,1)
plt.title(f'({fignums[0]}) SST {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax1.pcolormesh(sst_mismatch.lon, sst_mismatch.lat, sst_mismatch,
                     cmap=cm.roma_r, vmin=0, vmax=16, zorder=0)
ax1.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)

cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='both')
cb.set_label(t_label, rotation=-90, labelpad=13)
ax1.set_ylim([-55,-30])
basin_bdy()

ax2 = fig.add_subplot(3,1,2)
plt.title(f'({fignums[1]}) Chl-a {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax2.pcolormesh(chl_mismatch.lon, chl_mismatch.lat, chl_mismatch,
                     cmap=cm.roma_r, vmin=0., vmax =0.5, zorder=0)
ax2.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(chl_label, rotation=-90, labelpad=13)
ax2.set_ylim([-55,-30])
basin_bdy()

ax3 = fig.add_subplot(3,1,3)
plt.title(f'({fignums[2]}) MLD {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax3.pcolormesh(mld_mismatch.lon, mld_mismatch.lat, mld_mismatch,
                     cmap=cm.roma_r, vmin=0, vmax=300,zorder=0)
ax3.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(mld_label, rotation=-90, labelpad=13)
ax3.set_ylim([-55,-30])
basin_bdy()

# %%
biome, biomestr = [14], "IND-STPS"
fignums = ("d", "e", "f")
plt.rcParams['hatch.linewidth'] = 0.5
plt.rcParams.update({'hatch.color': 'grey'})
fig = plt.figure(figsize=(12, 9))
#plot_vars(biome, biomestr, fignums)

sst_mismatch, mld_mismatch, chl_mismatch = get_mismatch(biome)

ax1 = fig.add_subplot(3,1,1)
plt.title(f'({fignums[0]}) SST {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax1.pcolormesh(sst_mismatch.lon, sst_mismatch.lat, sst_mismatch,
                     cmap=cm.roma_r, vmin=0, vmax=22, zorder=0)
ax1.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='both')
cb.set_label(t_label, rotation=-90, labelpad=13)
ax1.set_ylim([-55,-30])

ax2 = fig.add_subplot(3,1,2)
plt.title(f'({fignums[1]}) Chl-a {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax2.pcolormesh(chl_mismatch.lon, chl_mismatch.lat, chl_mismatch,
                     cmap=cm.roma_r, vmin=0., vmax =0.5, zorder=0)
ax2.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(chl_label, rotation=-90, labelpad=13)
ax2.set_ylim([-55,-30])

ax3 = fig.add_subplot(3,1,3)
plt.title(f'({fignums[2]}) MLD {biomestr} mismatch',loc='left',fontsize=12)
mesh = ax3.pcolormesh(mld_mismatch.lon, mld_mismatch.lat, mld_mismatch,
                     cmap=cm.roma_r, vmin=0, vmax=300,zorder=0)
ax3.pcolor(b_overlap.lon, b_overlap.lat, b_overlap,hatch='///',alpha=0.,zorder=6)
cb = plt.colorbar(mesh, shrink=0.8, aspect = 25, pad = 0.08, extend='max')
cb.set_label(mld_label, rotation=-90, labelpad=13)
ax3.set_ylim([-55,-30])
# Out:
# (-55.0, -30.0)

# %% [markdown]
# ### IND-STPS (Indian): SST ≥ 11°C, Summer Chl-a < 0.25 g m-3. Biome 14

# %%
str02 = f"Subtropical Permanently Stratified (Indian): \SST ≥ 11 \u00b0C, Summer Chl-a < 0.25 mg m\u207B\u00B3"

# %%
biome, biomestr = [14], "IND-STPS"
fignums = ("d", "e", "f")
fig = plt.figure(figsize=(12, 6))
plot_vars(biome, biomestr, fignums)
plt.savefig(f"../figures/S10_02.png", dpi=400, bbox_inches='tight')

# %% [markdown]
# ### SO-STSS Criteria:
#
# SST >= 8 degree C, chl-a >=0.16, or SST >= 8 degree C, maxMLD > 150 m
# (we use this option as chl-a is less well represented in B12)
# Referred as biome 15.

# %%
str03 = f"Subtropical Seasonally Stratified (SO) SO-STSS: SST ≥ 8 \u00b0C, Summer Chl-a > 0.16 mg m\u207B\u00B3 or max MLD > 150 m"

# %%
biome, biomestr = [15], "SO-STSS"
fignums = ["g", "h", "i"]
fig = plt.figure(figsize=(12, 6))
plot_vars(biome, biomestr, fignums)
plt.savefig(f"../figures/S10_03.png", dpi=400, bbox_inches='tight')

# %% [markdown]
# ### SH_SPSS Criteria: SST < 8 degree C Referred as biome 16.

# %%
str04 = f"SO-SPSS: SST < 8 \u00b0C"

# %%
bibiome, biomestr = [16], "SO-SPSS"
fignums = ["j", "k", "l"]
fig = plt.figure(figsize=(12, 6))
plot_vars(biome, biomestr, fignums)
plt.savefig(f"../figures/S10_04.png", dpi=400, bbox_inches='tight')

# %% [markdown]
# ## Put images together

# %%
from PIL import Image
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 
fdir = '/Users/nchang/opt/anaconda3/pkgs/mscorefonts-0.0.1-3/fonts'
fdir = '/Users/nchang/anaconda3/pkgs/matplotlib-base-3.8.3-py311hb58f1d1_0/lib/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf'

# %% [markdown]
# ### Only subtropical zones

# %%
im1 = Image.open(f'../figures/S10_01.png')
im2 = Image.open(f'../figures/S10_02.png')
im3 = Image.open(f'../figures/S10_03.png')

topbar = 100
font_ht = 50
ht = im1.height+font_ht+20
font = ImageFont.truetype(f'{fdir}/DejaVuSans-Bold.ttf', font_ht)


im_final  = Image.new('RGB', (im1.width, 3*(topbar+im1.height)), (255, 255, 255))
draw = ImageDraw.Draw(im_final)

draw.text((30, 20), str01, font=font, fill='black')
im_final.paste(im1,(0, 80))

draw.text((30, 20+ht), str02, font=font, fill='black')
im_final.paste(im2,(0, 80+ht))

draw.text((30, 20+ht*2), str03, font=font, fill='black')
im_final.paste(im3,(0, 80+ht*2))

im_final.show()
im_final.save(f'../figures/S10.png', bbox_inches='tight')

# %% [markdown]
# ### Include SPSS

# %%
im1 = Image.open(f'../figures/S10_01.png')
im2 = Image.open(f'../figures/S10_02.png')
im3 = Image.open(f'../figures/S10_03.png')
im4 = Image.open(f'../figures/S10_04.png')

topbar = 100
font_ht = 60
ht = im1.height+font_ht+20
font = ImageFont.truetype(f'{fdir}/DejaVuSans-Bold.ttf', font_ht)


im_final  = Image.new('RGB', (im1.width, 4*(topbar+im1.height)), (255, 255, 255))
draw = ImageDraw.Draw(im_final)

draw.text((30, 10), str01, font=font, fill='black')
im_final.paste(im1,(0, 80))

draw.text((30, ht), str02, font=font, fill='black')
im_final.paste(im2,(0, 80+ht))

draw.text((30, ht*2), str03, font=font, fill='black')
im_final.paste(im3,(0, 80+ht*2))

draw.text((30, ht*3), str04, font=font, fill='black')
im_final.paste(im4,(0, 80+ht*3))
im_final.show()
#im_final.save(f'../figures/S10.png', bbox_inches='tight')
